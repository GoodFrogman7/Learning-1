# %% [markdown]
# <a href="https://colab.research.google.com/github/GoodFrogman7/Learning-1/blob/main/data_integrity_with_business_objectives_in_data_analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This lecture focuses on the importance of data integrity and aligning data with business objectives in data analysis.

# %% [markdown]
# ***Data Integrity and Business Objectives***
#
# Always ensure data integrity before analysis as unclean data leads to inaccurate insights.
#
# Understand the relationship between data and business objectives to pull relevant data for analysis.

# %% [markdown]
# # Data Limitations and Solutions
#
#
#
# *   Duplicate data can create misleading calculations, requiring data format adjustments or alternative calculation methods.
#
# *  Insufficient data can hinder accurate analysis, necessitating process changes or seeking additional data sources.

# %% [markdown]
# ![Screenshot 2024-12-19 123229.png](data:image/png;base64,...)

# %% [markdown]
# # DECISION TREE![Screenshot 2024-12-19 123403.png](data:image/png;base64,...)

# %% [markdown]
# # concept of sample size and its importance in data analysis
#
#   understanding Sample size:
#
# 1. A population refers to all possible data values in a dataset, while a sample represents a smaller, representative portion of that population.
#
# 2.Sample size is crucial when studying large populations, as gathering data from every individual can be impractical due to time and cost constraints.
#
# #Benefits and Challenges of Using Samples
#
#
# 1.Analyzing a carefully selected sample can yield similar results to analyzing an entire population, offering a more efficient approach.
#
# 2.However, relying on a sample introduces a degree of uncertainty, as it might not perfectly reflect the entire population, potentially leading to sampling bias.
#
# #Addressing Sampling Bias
#
# 1.Sampling bias occurs when a sample doesn't accurately represent the population, leading to over-representation or under-representation of certain groups.
#
# 2.Random sampling helps mitigate sampling bias by ensuring every member of the population has an equal chance of being included in the sample.

# %% [markdown]
# # Calculate sample size![Screenshot 2024-12-19 124426.png](data:image/png;base64,...)

# %% [markdown]
# #Things to remember when determining the size of your sample
#
#
# 1. Don’t use a sample size less than 30. It has been statistically proven that 30 is the smallest sample size where an average result of a sample starts to represent the average result of a population.
#
# 2.The confidence level most commonly used is 95%, but 90% can work in some cases.
#
#
# **Increase the sample size to meet specific needs of your project:**
#
# 1.   For a higher confidence level, use a larger sample size
#
#
# 2.   To decrease the margin of error, use a larger sample size
#
#
#
# 3.   For greater statistical significance, use a larger sample size

# %% [markdown]
# #USE A SAMPLE SIZE CALCULATOR
# - A sample size calculator is also a great tool for this. Sample size calculators let you enter a desired confidence level and margin of error for a given population size. They then calculate the sample size needed to statistically achieve those results.

# %% [markdown]
# # When data isn't readily available![Screenshot 2024-12-19 125905.png](data:image/png;base64,...)

# %% [markdown]
# # Glossary terms from module 1
#
# *Accuracy: The degree to which the data conforms to the actual entity being measured or described
#
#
# *Completeness: The degree to which the data contains all desired components or measures
#
# *Confidence interval:  A range of values that conveys how likely a statistical estimate reflects the population
#
# *Confidence level: The probability that a sample size accurately reflects the greater population
#
# *Consistency: The degree to which data is repeatable from different points of entry or collection
#
# *Cross-field validation: A process that ensures certain conditions for multiple data fields are satisfied
#
# *Data constraints: The criteria that determine whether a piece of a data is clean and valid
#
# *Data integrity: The accuracy, completeness, consistency, and trustworthiness of data throughout its life cycle
#
# *Data manipulation: The process of changing data to make it more organized and easier to read
#
# *Data range: Numerical values that fall between predefined maximum and minimum values
#
# *Data replication: The process of storing data in multiple locations
#
# *DATEDIF: A spreadsheet function that calculates the number of days, months, or years between two dates
#
# *Estimated response rate: The average number of people who typically complete a survey
#
# *Hypothesis testing: A process to determine if a survey or experiment has meaningful results
#
# *Mandatory: A data value that cannot be left blank or empty
#
# *Margin of error: The maximum amount that the sample results are expected to differ from those of the actual population
#
# *Random sampling: A way of selecting a sample from a population so that every possible type of the sample has an equal chance of being chosen
#
# *Regular expression (RegEx): A rule that says the values in a table must match a prescribed pattern

# %% [markdown]
# # **This lesson focuses on the importance of clean data for effective data analysis.**
#
#
#
#
# *  *Data Importance*
#
#
#     Clean data is crucial for meaningful analysis, leading to better decision-making.
#
#     Dirty data, on the other hand, can result in inaccurate analysis and potentially costly consequences.
#
#
#
# * *Data Professionals*
#
#
#       Data engineers and data warehousing specialists play a vital role in ensuring data quality.
#
#       They transform, store, and organize data, making it more usable for analysts.

# %% [markdown]
# ![Screenshot 2024-12-21 103110.png](data:image/png;base64,...)

# %% [markdown]
# # **Common data-cleaning pitfalls**
# ![Screenshot 2024-12-21 104855.png](data:image/png;base64,...)

# %% [markdown]
# #  **Data cleaning in excel:**
#     Use *COUNTIF* to find numbers lower than 100
# Open the  International
# Logistics Association Memberships - Data for Cleaning
#  dataset, and scroll down to row 73.
#
# **Note: The dataset has 71 rows, and row 72 is left blank for separation.**
#
#     In cell H73,
#
#     enter Member Dues < 100 to label the calculation.
#
#
#     In cell I73, enter the formula =COUNTIF(I2:I71,"<100")
#
# [*to count how many members in the cell range I2:I72 pay dues of less than $100. This formula returns a value of 1, indicating one value is below $100.*]![Screenshot 2024-12-21 114317.png](data:image/png;base64,...)
#
#
#
#     In cell I54, change -$200 to $200. Cell I74 should now display the value 0.

# %% [markdown]
# ![Screenshot 2024-12-21 115237.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-21 115250.png](data:image/png;base64,...)

# %% [markdown]
# # Example 4: The LEFT and RIGHT functions
#
# 1.  LEFT is a function that returns a set number of characters from the left side of a text string.
#
# 2. RIGHT is a function that returns a set number of characters from the right side of a text string.

# %% [markdown]
# ![Screenshot 2024-12-21 115706.png](data:image/png;base64,...)

# %% [markdown]
# #Example 5: The **MID function**
# ![Screenshot 2024-12-21 115812.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-21 120122.png](data:image/png;base64,...)

# %% [markdown]
# # Example 6: The **CONCATENATE function**
# ![Screenshot 2024-12-21 120232.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-21 120437.png](data:image/png;base64,...)

# %% [markdown]
# # Example 7: **TRIM function**![Screenshot 2024-12-21 120517.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-21 120543.png](data:image/png;base64,...)

# %% [markdown]
# # Example 3: **Plotting![Screenshot 2024-12-21 193603.png](data:image/png;base64,...)**

# %% [markdown]
# ![Screenshot 2024-12-21 193611.png](data:image/png;base64,...)

# %% [markdown]
# # Spreadsheets functions and formulas or SQL queries?

# %% [markdown]
# Before they can address this question, this data analyst needs to choose what tool to use. First, they have to think about where the data lives. If it is stored in a database, then SQL is the best tool for the job. But if it is stored in a spreadsheet, then they will have to perform their analysis in that spreadsheet. In that scenario, they could create a pivot table of the data and then apply specific formulas and filters to their data until they were given the number of users that joined after February 15th. It isn’t a really complicated process, but it would involve a lot of steps.

# %% [markdown]
#  **In this case, the data is stored in a database, so they will have to work with SQL. And this data analyst knows they could get the same results with a single SQL query: **

# %% [markdown]
# ![Screenshot 2024-12-25 153655.png](data:image/png;base64,...)

# %% [markdown]
# # Spreadsheets and SQL both have their advantages and disadvantages:![Screenshot 2024-12-25 154421.png](data:image/png;base64,...)
